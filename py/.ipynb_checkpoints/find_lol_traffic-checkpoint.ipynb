# %%
from bat import log_to_dataframe

# %%
df = log_to_dataframe.LogToDataFrame('./test_2/ssl.log')
# Out:
# Successfully monitoring ./test_2/ssl.log...

# %%
df.head()
# Out:
#                                                  cert_chain_fuids  \
# ts
# 2018-12-13 16:42:04.922101    F0ejtL10tu9WcnkLj,FuX2hbVuT8R54j0ll
# 2018-12-13 16:42:05.046896   FKQGOJ2es2F2eWkw4,FfJb6z1uoahUfwcdf2
# 2018-12-13 16:42:06.022528  FbPqrV2ecKcv57HkF1,FrmnKb2wqoQ8XdgbTi
# 2018-12-13 16:42:08.555239  Fog5Ty4bTRnHQGlQic,FizPFf1I86WSMR4gs7
# 2018-12-13 16:42:09.581732  FB9Ex51A77FEb9Bbb6,FmnjKw2OBRUY6tIF2h
#
#                                                            cipher  \
# ts
# 2018-12-13 16:42:04.922101  TLS_ECDHE_RSA_WITH_AES_256_CBC_SHA384
# 2018-12-13 16:42:05.046896  TLS_ECDHE_RSA_WITH_AES_128_GCM_SHA256
# 2018-12-13 16:42:06.022528  TLS_ECDHE_RSA_WITH_AES_128_GCM_SHA256
# 2018-12-13 16:42:08.555239  TLS_ECDHE_RSA_WITH_AES_128_GCM_SHA256
# 2018-12-13 16:42:09.581732  TLS_ECDHE_RSA_WITH_AES_128_GCM_SHA256
#
#                            client_cert_chain_fuids client_issuer  \
# ts
# 2018-12-13 16:42:04.922101                 (empty)             -
# ...

# %%
print(df)
# Out:
#                                                              cert_chain_fuids  \
# ts
# 2018-12-13 16:42:04.922101                F0ejtL10tu9WcnkLj,FuX2hbVuT8R54j0ll
# 2018-12-13 16:42:05.046896               FKQGOJ2es2F2eWkw4,FfJb6z1uoahUfwcdf2
# 2018-12-13 16:42:06.022528              FbPqrV2ecKcv57HkF1,FrmnKb2wqoQ8XdgbTi
# 2018-12-13 16:42:08.555239              Fog5Ty4bTRnHQGlQic,FizPFf1I86WSMR4gs7
# 2018-12-13 16:42:09.581732              FB9Ex51A77FEb9Bbb6,FmnjKw2OBRUY6tIF2h
# 2018-12-13 16:42:09.551055              FepFUX2qHROKw6nGn9,FtzmZx3XqlKSAPxun5
# 2018-12-13 16:42:09.990451               Fr8xAr3uTUWAT8dUH3,FZuisH2EVRg7E331j
# 2018-12-13 16:42:10.137672               Fza7ZDTaTkxWL8qm7,FCyECR2PqPKYznMtM8
# 2018-12-13 16:42:10.666429              FjK4AQ1HVZbX3tak0l,FiF1UE4BVqIRCCObjk
# 2018-12-13 16:42:11.797627              FlvozS3JOGG2Q7ZYyj,FEpvAQ2DZioC84Jwl5
# 2018-12-13 16:42:12.118577              F1AiRh3PXtcDHLI8A5,FTb9Pl1SrCIG35PE0f
# ...

# %%
df?
# Out:
# Type:           LogToDataFrame
# String form:
# cert_chain_fuids  \
#            ts               <...> OTDps9  TLSv12
#            2018-12-13 16:46:43.271061  CDFZwx1Z7cLHpuox6i  TLSv12
#
#            [91 rows x 19 columns]
# Length:         91
# File:           ~/.local/lib/python3.5/site-packages/bat/log_to_dataframe.py
# Docstring:
# LogToDataFrame: Converts a Bro log to a Pandas DataFrame
# Args:
#     log_fllename (string): The full path to the Bro log
#     ts_index (bool): Set the index to the 'ts' field (default = True)
# Notes:
#     This class is fairly simple right now but will probably have additional
#     functionality for formal type specifications and performance enhancements
# Init docstring: Initialize the LogToDataFrame class

# %%
print(df.loc[df['id.orig_p']]>=50000)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-105b3f973d2c> in <module>
# ----> 1 print(df.loc[df['id.orig_p']]>=50000)
#
# ~/.local/lib/python3.5/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1476
#    1477             maybe_callable = com._apply_if_callable(key, self.obj)
# -> 1478             return self._getitem_axis(maybe_callable, axis=axis)
#    1479
#    1480     def _is_scalar_access(self, key):
#
# ~/.local/lib/python3.5/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1899                     raise ValueError('Cannot index with multidimensional key')
#    1900
# -> 1901                 return self._getitem_iterable(key, axis=axis)
#    1902
#    1903             # nested tuple slicing
#
# ~/.local/lib/python3.5/site-packages/pandas/core/indexing.py in _getitem_iterable(self, key, axis)
# ...
